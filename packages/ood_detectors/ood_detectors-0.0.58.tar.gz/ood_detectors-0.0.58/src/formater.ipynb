# %%
import yaml
import glob

# %%
file = "results.yaml"

with open(file, "r") as f:
    results = yaml.load(f, Loader=yaml.FullLoader)

# %%
def add_dicts(dest, src):
    for k, v in src.items():
        if k in dest:
            if isinstance(v, dict):
                add_dicts(dest[k], v)
            else:
                raise ValueError(f"Key {k} already exists in {dest}")
        else:
            dest[k] = v

# %%
results = {}
for file in glob.glob("results/*.yaml"):
    print(file)
    with open(file, "r") as f:
        data = yaml.load(f, Loader=yaml.FullLoader)
        add_dicts(results, data)
# Out:
# results/VESDE_dinov2_imagenet_sub.yaml
# results/subVPSDE_vit_imagenet.yaml
# results/VESDE_vit_imagenet200.yaml
# results/Residual_resnet18_32x32_cifar100_open_ood_cifar100.yaml
# results/VESDE_swin_imagenet.yaml
# results/Residual_resnet50d_imagenet200.yaml
# results/Residual_dinov2_imagenet_sub.yaml
# results/VESDE_resnet50d_imagenet.yaml
# results/VESDE_deit_imagenet.yaml
# results/VESDE_dinov2_imagenet.yaml
# results/VESDE_swin_imagenet200.yaml
# results/VESDE_dino_imagenet.yaml
# results/subVPSDE_resnet50d_imagenet.yaml
# results/VPSDE_clip_imagenet.yaml
# results/Residual_repvgg_imagenet_sub.yaml
# results/Residual_resnet18_32x32_cifar10_open_ood_cifar10.yaml
# results/VPSDE_dino_imagenet_sub.yaml
# results/VESDE_repvgg_imagenet_sub.yaml
# results/VPSDE_resnet18_224x224_imagenet200_open_ood_imagenet200.yaml
# results/Residual_swin_imagenet200.yaml
# results/VPSDE_dino_imagenet.yaml
# results/Residual_vit_imagenet200.yaml
# results/subVPSDE_resnet18_224x224_imagenet200_open_ood_imagenet200.yaml
# results/VESDE_clip_imagenet.yaml
# results/VESDE_dino_imagenet_sub.yaml
# results/VESDE_repvgg_imagenet200.yaml
# results/Residual_deit_imagenet200.yaml
# results/Residual_vit_imagenet.yaml
# results/Residual_swin_imagenet_sub.yaml
# results/Residual_deit_imagenet_sub.yaml
# results/subVPSDE_repvgg_imagenet.yaml
# results/subVPSDE_vit_imagenet_sub.yaml
# results/VPSDE_vit_imagenet_sub.yaml
# results/VESDE_deit_imagenet200.yaml
# results/Residual_resnet18_224x224_imagenet200_open_ood_imagenet200.yaml
# results/VESDE_resnet18_32x32_cifar10_open_ood_cifar10.yaml
# results/VPSDE_repvgg_imagenet.yaml
# results/subVPSDE_dinov2_imagenet200.yaml
# results/Residual_clip_imagenet200.yaml
# results/VESDE_dino_imagenet200.yaml
# results/VESDE_vit_imagenet.yaml
# results/subVPSDE_dino_imagenet_sub.yaml
# results/Residual_dinov2_imagenet.yaml
# results/VESDE_dinov2_imagenet200.yaml
# results/VPSDE_deit_imagenet.yaml
# results/subVPSDE_repvgg_imagenet200.yaml
# results/Residual_dino_imagenet200.yaml
# results/VESDE_clip_imagenet200.yaml
# results/VPSDE_swin_imagenet.yaml
# results/VPSDE_clip_imagenet200.yaml
# results/subVPSDE_clip_imagenet200.yaml
# results/subVPSDE_resnet18_32x32_cifar10_open_ood_cifar10.yaml
# results/Residual_resnet50d_imagenet.yaml
# results/VPSDE_repvgg_imagenet200.yaml
# results/subVPSDE_dino_imagenet.yaml
# results/subVPSDE_deit_imagenet_sub.yaml
# results/subVPSDE_swin_imagenet_sub.yaml
# results/VESDE_resnet50_224x224_imagenet_open_ood_imagenet.yaml
# results/Residual_swin_imagenet.yaml
# results/VESDE_repvgg_imagenet.yaml
# results/Residual_deit_imagenet.yaml
# results/VPSDE_dino_imagenet200.yaml
# results/subVPSDE_dino_imagenet200.yaml
# results/VESDE_resnet18_32x32_cifar100_open_ood_cifar100.yaml
# results/VPSDE_vit_imagenet.yaml
# results/VPSDE_dinov2_imagenet200.yaml
# results/subVPSDE_deit_imagenet.yaml
# results/subVPSDE_deit_imagenet200.yaml
# results/VPSDE_deit_imagenet200.yaml
# results/Residual_dino_imagenet_sub.yaml
# results/Residual_dino_imagenet.yaml
# results/VESDE_vit_imagenet_sub.yaml
# results/VPSDE_resnet18_32x32_cifar100_open_ood_cifar100.yaml
# results/subVPSDE_resnet50d_imagenet200.yaml
# results/subVPSDE_swin_imagenet.yaml
# results/Residual_vit_imagenet_sub.yaml
# results/Residual_resnet50d_imagenet_sub.yaml
# results/VESDE_deit_imagenet_sub.yaml
# results/VESDE_swin_imagenet_sub.yaml
# results/Residual_resnet50_224x224_imagenet_open_ood_imagenet.yaml
# results/subVPSDE_resnet50d_imagenet_sub.yaml
# results/VESDE_resnet18_224x224_imagenet200_open_ood_imagenet200.yaml
# results/VPSDE_vit_imagenet200.yaml
# results/Residual_clip_imagenet.yaml
# results/subVPSDE_repvgg_imagenet_sub.yaml
# results/subVPSDE_vit_imagenet200.yaml
# results/VPSDE_resnet18_32x32_cifar10_open_ood_cifar10.yaml
# results/VPSDE_swin_imagenet_sub.yaml
# results/VPSDE_deit_imagenet_sub.yaml
# results/subVPSDE_resnet18_32x32_cifar100_open_ood_cifar100.yaml
# results/subVPSDE_resnet50_224x224_imagenet_open_ood_imagenet.yaml
# results/VPSDE_resnet50_224x224_imagenet_open_ood_imagenet.yaml
# results/VPSDE_resnet50d_imagenet.yaml
# results/VESDE_resnet50d_imagenet_sub.yaml
# results/Residual_repvgg_imagenet200.yaml
# results/Residual_repvgg_imagenet.yaml
# results/subVPSDE_swin_imagenet200.yaml
# results/VPSDE_swin_imagenet200.yaml
# results/VPSDE_repvgg_imagenet_sub.yaml
# results/subVPSDE_dinov2_imagenet.yaml
# results/VESDE_resnet50d_imagenet200.yaml
# results/VPSDE_dinov2_imagenet.yaml
# results/VPSDE_dinov2_imagenet_sub.yaml
# results/VPSDE_resnet50d_imagenet_sub.yaml
# results/Residual_dinov2_imagenet200.yaml
# results/subVPSDE_clip_imagenet.yaml
# results/subVPSDE_dinov2_imagenet_sub.yaml
# results/VPSDE_resnet50d_imagenet200.yaml

# %%
results.keys()
# Out:
# dict_keys(['VESDE', 'subVPSDE', 'Residual', 'VPSDE'])

# %%
def multicol(name, space=2, bars=False):
    if bars:
        return r"\multicolumn{" +str(space)+r"}{|c|}{\textbf{" + name + r"}}"
    return r"\multicolumn{" +str(space)+r"}{c}{\textbf{" + name + r"}}"

def get_names(data, dataset):
    far_names = None
    near_names = None
    for d in data.values():
        if dataset not in d:
            continue
        far_names = []
        near_names = []

        for _dataset in d[dataset]["farood"]:
            far_names.append(_dataset["dataset"])
       
        for _dataset in d[dataset]["nearood"]:
            near_names.append(_dataset["dataset"])

        return far_names, near_names
    return far_names, near_names
def create_latex_table(result, method, dataset, encoders):
    far_names, near_names = get_names(result[method], dataset)
    if far_names is None:
        return ""
    
    print(far_names, near_names)

    total_items = len(far_names) + len(near_names)

    header = r"\begin{table}[ht]"+ "\n"
    header += r"\caption{" +f'Result for '+ method.replace("_", "\\_") + ' on '+ dataset.replace("_", "\\_") + r"}"+ "\n"

    header += r"""\centering
\resizebox{\textwidth}{!}{% Resize table to fit within \textwidth horizontally
"""
    header += r"\begin{tabular}{@{}l*{" + str(total_items+1) + r"}{SS}@{}}" + "\n"
    header += r"\toprule" + "\n"

    description = r"\textbf{Encoder} & "  + " & ".join(multicol(name.replace("_", r"\_")) for name in near_names+far_names ) + multicol("Average") + r" \\" + "\n"
    description +=  r" & {\footnotesize AUROC} $\uparrow$ & {\footnotesize FPR95} $\downarrow$ "*(total_items +1)+ r" \\" + "\n"
    midrule = r"\midrule" + "\n"
    footer = r"\label{tab:" + f"{method}_{dataset}" + r"}" + "\n"
    footer += r"""
\bottomrule
\end{tabular}
}
\end{table}
"""+"\n"

    rows = [" & "   + multicol("Near OOD", len(near_names)*2, True) + " & " + multicol("Far OOD", len(far_names)*2, True) + r" & \\" + "\n"]
    # rows = []

    lookup = {}
    max_data = {}
    for encoder in sorted(encoders):
        if encoder not in result[method]:
            continue
        if dataset not in result[method][encoder]:
            continue
        for name, data in result[method][encoder][dataset].items():
            if name not in ["nearood", "farood"]:
                continue
            lookup_tmp = {d["dataset"]: d["metrics"] for d in data}
            if encoder not in lookup:
                lookup[encoder] = {}
            lookup[encoder].update(lookup_tmp)
 
    for e in encoders:
        if e not in lookup:
            continue
        for data_name in lookup[e]:
            if data_name not in lookup[e]:
                continue
            if data_name not in max_data:
                max_data[data_name] = {
                    "AUC": 0,
                    "FPR_95": 1
                }
            if lookup[e][data_name]["AUC"] > max_data[data_name]["AUC"]:
                max_data[data_name]["AUC"] = lookup[e][data_name]["AUC"]
            if lookup[e][data_name]["FPR_95"] < max_data[data_name]["FPR_95"]:
                max_data[data_name]["FPR_95"] = lookup[e][data_name]["FPR_95"]

    for encoder in sorted(encoders):
        if encoder not in result[method]:
            continue
        if dataset not in result[method][encoder]:
            continue
        if "resnet18_" in encoder:
            row = [r"resnet18\_open\_ood"]
        elif "resnet50_" in encoder:
            row = [r"resnet50\_open\_ood"]
        else:
            row = [encoder]
        avg_auc = 0
        avg_fpr = 0
        count = 0
        for data_names in near_names + far_names:
            data_res = max_data[data_names]
            max_auc = data_res["AUC"]
            min_fpr = data_res["FPR_95"]
            if data_names in lookup[encoder]:
                metrics = lookup[encoder][data_names]
                if metrics["AUC"] == max_auc:
                    row.append(r"\textbf{" + f"{metrics['AUC']*100:.2f}" + r"}")
                else:
                    row.append(f"{metrics['AUC']*100:.2f}")
                avg_auc += metrics["AUC"]
                if metrics["FPR_95"] == min_fpr:
                    row.append(r"\textbf{" + f"{metrics['FPR_95']*100:.2f}" + r"}")
                else:
                    row.append(f"{metrics['FPR_95']*100:.2f}")
                avg_fpr += metrics["FPR_95"]
                count += 1
            else:
                row.append("-")
                row.append("-")
        print(row)
        row.append(f"{avg_auc/count*100:.2f}")
        row.append(f"{avg_fpr/count*100:.2f}")
        rows.append(" & ".join(row) + r" \\")

    return header + description + midrule + "\n".join(rows) + footer

# Generate the LaTeX table
datasets = ['imagenet_sub', 'imagenet','imagenet200', 'cifar10', 'cifar100']
encoders = [ 'dino', 'dinov2', 'vit', 'clip', 'repvgg', 'resnet50d', 'swin', 'deit'] + ['resnet18_32x32_cifar10_open_ood', 'resnet18_32x32_cifar100_open_ood', 'resnet18_224x224_imagenet200_open_ood', 'resnet50_224x224_imagenet_open_ood']
with open("out.txt", "w") as f:
    for method, result in results.items():
        for dataset in datasets:
            f.write(create_latex_table(results, method, dataset, encoders))
# Out:
# ['openimageo', 'inaturalist', 'textures'] ['imagenet-o']
# ['deit', '75.25', '89.80', '87.92', '66.69', '90.04', '63.21', '82.17', '78.39']
# ['dino', '81.59', '71.65', '86.71', '60.79', '87.97', '66.29', '\\textbf{97.43}', '\\textbf{12.87}']
# ['dinov2', '85.56', '65.45', '93.88', '31.41', '\\textbf{99.33}', '\\textbf{1.27}', '93.43', '32.38']
# ['repvgg', '76.00', '79.85', '80.95', '70.91', '83.06', '72.77', '92.59', '31.71']
# ['resnet50d', '79.76', '72.65', '85.52', '61.16', '85.20', '68.03', '93.87', '28.99']
# ['swin', '85.43', '72.40', '93.53', '39.62', '98.07', '9.33', '89.96', '50.52']
# ['vit', '\\textbf{90.18}', '\\textbf{44.95}', '\\textbf{95.16}', '\\textbf{25.20}', '98.68', '6.95', '93.39', '28.76']
# ['textures', 'openimageo', 'inaturalist'] ['imagenet-o', 'ninco', 'ssb_hard']
# ['clip', '67.74', '90.75', '59.69', '93.96', '53.27', '95.67', '70.85', '94.15', '76.78', '86.05', '61.69', '99.43']
# ['deit', '75.81', '89.80', '78.99', '82.14', '64.24', '91.61', '83.08', '76.80', '87.08', '71.04', '88.29', '71.74']
# ['dino', '81.37', '73.30', '80.26', '75.08', '58.89', '92.06', '\\textbf{97.04}', '\\textbf{15.25}', '88.06', '58.48', '87.38', '70.76']
# ['dinov2', '84.31', '66.50', '87.63', '55.16', '78.08', '67.76', '93.53', '31.88', '93.96', '30.98', '\\textbf{99.35}', '\\textbf{1.51}']
# ['repvgg', '72.77', '86.90', '65.73', '90.88', '48.63', '96.17', '88.87', '47.07', '77.65', '79.14', '77.59', '86.58']
# ['resnet50\\_open\\_ood', '82.21', '65.35', '61.58', '94.25', '46.56', '97.20', '93.81', '30.43', '71.09', '84.11', '64.58', '92.97']
# ['resnet50d', '80.93', '72.30', '73.33', '85.30', '57.90', '92.22', '94.35', '27.62', '86.53', '62.40', '83.17', '77.59']
# ['swin', '84.70', '75.90', '85.62', '72.22', '71.54', '87.33', '89.99', '50.14', '93.91', '37.10', '97.94', '10.33']
# ['vit', '\\textbf{90.52}', '\\textbf{43.55}', '\\textbf{91.47}', '\\textbf{41.28}', '\\textbf{80.96}', '\\textbf{62.67}', '93.63', '27.56', '\\textbf{95.52}', '\\textbf{22.67}', '98.95', '5.05']
# ['textures', 'openimageo', 'inaturalist'] ['ssb_hard', 'imagenet-o', 'ninco']
# ['clip', '67.67', '86.85', '84.04', '72.50', '71.32', '83.38', '85.53', '77.13', '84.60', '73.52', '73.80', '96.62']
# ['deit', '79.93', '84.77', '87.82', '75.05', '85.98', '72.51', '91.23', '60.10', '91.26', '60.54', '90.88', '66.57']
# ['dino', '76.70', '77.12', '92.73', '36.60', '87.46', '61.15', '\\textbf{98.74}', '5.95', '92.80', '42.98', '91.71', '59.00']
# ['dinov2', '88.70', '36.18', '96.20', '16.55', '93.18', '36.11', '98.22', '\\textbf{5.16}', '97.93', '9.60', '\\textbf{99.21}', '\\textbf{0.73}']
# ['repvgg', '71.07', '84.45', '89.91', '44.30', '78.98', '77.63', '96.69', '14.92', '87.60', '56.61', '85.81', '74.95']
# ['resnet18\\_open\\_ood', '48.54', '95.99', '61.79', '88.55', '55.47', '94.30', '75.13', '73.43', '58.07', '91.57', '57.56', '93.80']
# ['resnet50d', '76.25', '81.43', '90.89', '45.35', '83.63', '70.88', '97.27', '13.41', '92.50', '42.88', '90.11', '58.69']
# ['swin', '84.04', '75.80', '92.53', '51.50', '90.75', '56.80', '95.18', '27.09', '96.51', '22.43', '98.59', '6.32']
# ['vit', '\\textbf{92.02}', '\\textbf{31.08}', '\\textbf{97.70}', '\\textbf{10.00}', '\\textbf{95.30}', '\\textbf{25.68}', '98.01', '6.20', '\\textbf{98.35}', '\\textbf{7.48}', '99.18', '2.82']
# ['mnist', 'place365', 'texture', 'svhn'] ['tin', 'cifar100']
# ['resnet18\\_open\\_ood', '\\textbf{49.58}', '\\textbf{97.54}', '\\textbf{49.29}', '\\textbf{97.53}', '\\textbf{55.67}', '\\textbf{95.61}', '\\textbf{48.71}', '\\textbf{97.89}', '\\textbf{56.79}', '\\textbf{97.43}', '\\textbf{50.22}', '\\textbf{96.67}']
# ['places365', 'mnist', 'svhn', 'texture'] ['cifar10', 'tin']
# ['resnet18\\_open\\_ood', '\\textbf{46.06}', '\\textbf{96.80}', '\\textbf{49.39}', '\\textbf{96.38}', '\\textbf{50.38}', '\\textbf{95.87}', '\\textbf{62.05}', '\\textbf{94.31}', '\\textbf{56.56}', '\\textbf{95.85}', '\\textbf{64.09}', '\\textbf{85.39}']
# ['inaturalist', 'textures', 'openimageo'] ['imagenet-o']
# ['deit', '75.26', '91.30', '87.14', '79.65', '81.90', '81.40', '86.51', '73.71']
# ['dino', '82.34', '69.95', '89.80', '62.15', '\\textbf{97.82}', '\\textbf{11.43}', '87.52', '58.75']
# ['dinov2', '85.71', '63.85', '\\textbf{99.14}', '\\textbf{1.73}', '93.65', '31.20', '93.96', '31.85']
# ['repvgg', '74.60', '85.15', '82.03', '77.58', '91.02', '39.01', '79.53', '75.25']
# ['resnet50d', '80.41', '74.55', '84.39', '75.99', '93.77', '30.16', '85.85', '64.41']
# ['swin', '84.67', '74.85', '97.78', '11.13', '89.36', '52.44', '93.03', '42.36']
# ['vit', '\\textbf{89.61}', '\\textbf{45.60}', '98.76', '6.13', '92.81', '31.76', '\\textbf{94.46}', '\\textbf{27.60}']
# ['textures', 'inaturalist', 'openimageo'] ['ssb_hard', 'ninco', 'imagenet-o']
# ['clip', '51.91', '95.72', '57.70', '95.49', '67.51', '91.40', '70.16', '94.40', '59.94', '99.55', '73.72', '87.21']
# ['deit', '64.19', '92.06', '78.49', '83.30', '75.61', '90.80', '82.83', '78.20', '87.62', '74.87', '86.74', '73.06']
# ['dino', '57.84', '92.29', '81.04', '73.91', '82.59', '70.75', '\\textbf{97.71}', '\\textbf{11.14}', '89.61', '64.83', '89.00', '55.34']
# ['dinov2', '78.97', '\\textbf{63.49}', '88.87', '51.76', '86.05', '61.05', '94.73', '25.37', '\\textbf{99.34}', '\\textbf{1.75}', '94.79', '27.15']
# ['repvgg', '48.53', '96.87', '65.73', '91.99', '72.00', '89.35', '87.72', '52.85', '75.78', '91.85', '76.59', '82.74']
# ['resnet50\\_open\\_ood', '45.61', '97.32', '61.60', '94.32', '82.07', '65.30', '93.20', '33.14', '64.98', '93.02', '70.12', '84.82']
# ['resnet50d', '59.23', '92.72', '74.36', '86.78', '78.76', '80.55', '92.10', '38.66', '82.07', '85.45', '85.75', '69.00']
# ['swin', '71.41', '87.13', '85.82', '71.39', '84.57', '75.65', '90.05', '48.41', '98.09', '9.92', '93.95', '36.47']
# ['vit', '\\textbf{81.19}', '63.84', '\\textbf{91.82}', '\\textbf{39.96}', '\\textbf{90.82}', '\\textbf{42.50}', '93.88', '25.74', '99.10', '4.14', '\\textbf{95.87}', '\\textbf{21.33}']
# ['inaturalist', 'openimageo', 'textures'] ['ssb_hard', 'imagenet-o', 'ninco']
# ['clip', '67.74', '88.64', '83.35', '75.95', '71.02', '87.96', '74.80', '98.27', '84.44', '77.38', '85.89', '80.95']
# ['deit', '79.96', '84.73', '88.07', '73.95', '86.89', '69.84', '92.53', '56.55', '92.06', '56.40', '91.39', '59.03']
# ['dino', '77.21', '77.03', '93.14', '35.05', '87.97', '59.52', '92.87', '53.81', '93.47', '40.03', '\\textbf{98.88}', '\\textbf{5.27}']
# ['dinov2', '88.92', '36.28', '96.26', '17.25', '93.38', '37.25', '\\textbf{99.26}', '\\textbf{0.77}', '97.99', '9.91', '98.22', '5.62']
# ['repvgg', '68.80', '89.49', '88.78', '52.75', '78.45', '80.86', '86.06', '80.25', '87.14', '61.55', '95.85', '20.02']
# ['resnet18\\_open\\_ood', '48.36', '96.36', '62.66', '89.35', '56.05', '94.10', '57.48', '94.07', '58.23', '92.35', '73.92', '75.00']
# ['resnet50d', '75.02', '85.91', '90.62', '50.45', '83.42', '73.74', '88.20', '73.72', '91.51', '50.90', '96.55', '19.73']
# ['swin', '83.65', '74.82', '92.62', '48.65', '91.04', '53.84', '98.73', '4.57', '96.52', '21.27', '94.99', '26.88']
# ['vit', '\\textbf{92.19}', '\\textbf{32.21}', '\\textbf{97.73}', '\\textbf{10.90}', '\\textbf{95.53}', '\\textbf{24.24}', '99.15', '2.77', '\\textbf{98.46}', '\\textbf{7.15}', '97.90', '6.55']
# ['mnist', 'place365', 'texture', 'svhn'] ['tin', 'cifar100']
# ['resnet18\\_open\\_ood', '\\textbf{81.61}', '\\textbf{72.98}', '\\textbf{80.86}', '\\textbf{72.52}', '\\textbf{80.53}', '\\textbf{87.16}', '\\textbf{79.13}', '\\textbf{77.18}', '\\textbf{90.14}', '\\textbf{48.62}', '\\textbf{86.57}', '\\textbf{69.49}']
# ['places365', 'mnist', 'svhn', 'texture'] ['cifar10', 'tin']
# ['resnet18\\_open\\_ood', '\\textbf{45.92}', '\\textbf{96.88}', '\\textbf{50.84}', '\\textbf{96.06}', '\\textbf{51.34}', '\\textbf{95.67}', '\\textbf{61.76}', '\\textbf{95.84}', '\\textbf{61.89}', '\\textbf{94.78}', '\\textbf{68.81}', '\\textbf{78.60}']
# ['openimageo', 'inaturalist', 'textures'] ['imagenet-o']
# ['deit', '75.25', '90.80', '87.94', '70.29', '90.45', '65.70', '82.30', '79.52']
# ['dino', '81.95', '68.70', '87.59', '54.27', '92.70', '43.34', '\\textbf{98.04}', '\\textbf{10.04}']
# ['dinov2', '83.65', '71.35', '92.47', '36.48', '\\textbf{99.16}', '\\textbf{1.96}', '93.47', '35.54']
# ['repvgg', '76.02', '79.10', '81.85', '67.98', '85.33', '67.56', '93.52', '27.17']
# ['resnet50d', '81.18', '73.00', '86.47', '62.86', '84.70', '75.69', '94.65', '25.72']
# ['swin', '86.68', '68.50', '\\textbf{94.40}', '\\textbf{33.73}', '98.89', '4.83', '91.29', '43.99']
# ['vit', '\\textbf{88.27}', '\\textbf{49.65}', '91.73', '36.25', '98.30', '8.25', '91.91', '35.60']
# ['textures', 'openimageo', 'inaturalist'] ['imagenet-o', 'ssb_hard', 'ninco']
# ['clip', '63.76', '92.25', '50.62', '96.52', '55.03', '97.55', '66.56', '97.31', '71.35', '90.44', '58.04', '99.76']
# ['deit', '75.44', '90.65', '67.15', '89.85', '80.68', '79.72', '82.66', '77.87', '88.16', '69.81', '91.21', '60.85']
# ['dino', '81.87', '69.40', '54.30', '92.60', '78.27', '74.55', '\\textbf{98.04}', '\\textbf{10.19}', '88.76', '50.70', '92.79', '43.05']
# ['dinov2', '83.49', '71.45', '79.67', '66.95', '85.45', '62.15', '93.58', '34.55', '93.02', '35.23', '\\textbf{99.20}', '\\textbf{1.89}']
# ['repvgg', '76.02', '79.15', '50.41', '94.08', '69.94', '85.73', '93.64', '26.61', '82.97', '65.74', '85.58', '66.73']
# ['resnet50\\_open\\_ood', '82.44', '63.60', '45.17', '97.13', '60.62', '94.10', '93.63', '30.45', '70.27', '83.50', '65.23', '91.69']
# ['resnet50d', '81.45', '72.25', '60.11', '90.27', '75.53', '83.48', '94.82', '24.57', '88.29', '57.35', '85.38', '74.07']
# ['swin', '86.51', '68.25', '75.03', '83.36', '\\textbf{87.63}', '63.70', '91.78', '41.18', '\\textbf{95.49}', '\\textbf{26.77}', '99.19', '3.68']
# ['vit', '\\textbf{88.34}', '\\textbf{49.00}', '\\textbf{82.15}', '\\textbf{63.17}', '85.75', '\\textbf{58.85}', '92.01', '35.17', '92.50', '33.64', '98.28', '8.58']
# ['openimageo', 'inaturalist', 'textures'] ['ssb_hard', 'ninco', 'imagenet-o']
# ['clip', '64.84', '90.23', '68.41', '89.76', '81.68', '79.70', '81.58', '80.10', '70.61', '98.86', '84.16', '83.43']
# ['deit', '81.80', '82.34', '88.36', '67.07', '88.97', '68.75', '92.69', '54.89', '93.00', '57.72', '92.25', '53.31']
# ['dino', '75.47', '78.85', '87.22', '59.19', '92.98', '34.90', '93.79', '36.30', '94.31', '40.70', '\\textbf{98.96}', '\\textbf{5.19}']
# ['dinov2', '89.16', '36.73', '92.42', '42.49', '96.16', '18.20', '97.88', '10.35', '99.22', '\\textbf{1.09}', '98.10', '5.76']
# ['repvgg', '73.08', '83.69', '80.65', '76.24', '90.61', '42.60', '88.30', '56.17', '85.90', '80.29', '97.07', '13.66']
# ['resnet18\\_open\\_ood', '45.95', '96.59', '53.48', '94.40', '59.69', '89.80', '57.06', '91.40', '58.42', '92.76', '74.04', '73.45']
# ['resnet50d', '76.71', '81.98', '84.05', '70.74', '91.45', '43.90', '92.46', '43.82', '88.94', '68.32', '97.55', '12.85']
# ['swin', '86.35', '65.25', '92.56', '43.53', '94.22', '36.50', '97.58', '13.26', '\\textbf{99.37}', '1.60', '96.18', '18.70']
# ['vit', '\\textbf{92.95}', '\\textbf{31.40}', '\\textbf{94.73}', '\\textbf{30.21}', '\\textbf{97.73}', '\\textbf{10.90}', '\\textbf{98.09}', '\\textbf{9.02}', '99.07', '3.68', '97.87', '7.05']
# ['mnist', 'place365', 'texture', 'svhn'] ['tin', 'cifar100']
# ['resnet18\\_open\\_ood', '\\textbf{83.21}', '\\textbf{69.73}', '\\textbf{82.09}', '\\textbf{70.62}', '\\textbf{82.44}', '\\textbf{81.96}', '\\textbf{80.56}', '\\textbf{74.49}', '\\textbf{91.71}', '\\textbf{42.02}', '\\textbf{90.97}', '\\textbf{53.63}']
# ['places365', 'mnist', 'svhn', 'texture'] ['cifar10', 'tin']
# ['resnet18\\_open\\_ood', '\\textbf{44.24}', '\\textbf{97.31}', '\\textbf{48.69}', '\\textbf{96.25}', '\\textbf{49.79}', '\\textbf{95.69}', '\\textbf{60.40}', '\\textbf{96.68}', '\\textbf{59.71}', '\\textbf{95.46}', '\\textbf{66.55}', '\\textbf{79.01}']
# ['openimageo', 'textures', 'inaturalist'] ['imagenet-o']
# ['deit', '75.18', '90.95', '87.08', '71.35', '82.16', '80.14', '88.35', '73.50']
# ['dino', '82.49', '69.05', '87.52', '58.72', '\\textbf{97.78}', '\\textbf{10.93}', '89.81', '61.43']
# ['dinov2', '85.94', '63.55', '94.09', '31.49', '93.52', '31.45', '\\textbf{99.24}', '\\textbf{1.56}']
# ['repvgg', '74.55', '84.00', '80.75', '71.89', '91.26', '36.96', '84.83', '69.22']
# ['resnet50d', '79.72', '76.00', '84.48', '66.76', '92.91', '33.90', '83.67', '74.97']
# ['swin', '84.43', '75.95', '92.71', '44.92', '89.19', '54.17', '97.53', '12.85']
# ['vit', '\\textbf{89.60}', '\\textbf{47.55}', '\\textbf{94.38}', '\\textbf{28.88}', '92.42', '33.70', '98.69', '6.42']
# ['inaturalist', 'textures', 'openimageo'] ['ssb_hard', 'ninco', 'imagenet-o']
# ['clip', '52.20', '95.70', '58.56', '94.91', '68.48', '90.50', '61.81', '99.36', '71.76', '94.09', '75.37', '86.38']
# ['deit', '64.54', '91.88', '79.33', '81.88', '75.93', '90.30', '88.20', '72.86', '83.28', '76.74', '87.11', '71.61']
# ['dino', '57.99', '92.37', '81.06', '73.65', '82.52', '70.20', '89.69', '63.32', '\\textbf{97.67}', '\\textbf{11.20}', '89.11', '54.40']
# ['dinov2', '78.65', '66.00', '88.11', '55.74', '85.69', '63.55', '\\textbf{99.36}', '\\textbf{1.49}', '93.88', '29.21', '94.40', '29.17']
# ['repvgg', '49.12', '96.59', '65.36', '91.61', '71.79', '88.45', '75.58', '91.13', '87.96', '51.55', '76.40', '82.19']
# ['resnet50\\_open\\_ood', '45.36', '97.32', '61.19', '94.45', '82.04', '64.70', '64.69', '92.62', '93.32', '32.81', '70.18', '84.21']
# ['resnet50d', '58.38', '91.81', '74.78', '84.03', '80.55', '74.60', '84.96', '76.09', '94.16', '28.93', '87.86', '59.81']
# ['swin', '71.79', '87.35', '85.84', '71.93', '84.67', '75.25', '98.05', '9.68', '90.23', '48.12', '94.01', '36.48']
# ['vit', '\\textbf{81.53}', '\\textbf{62.89}', '\\textbf{91.78}', '\\textbf{40.55}', '\\textbf{90.74}', '\\textbf{43.10}', '99.12', '4.35', '94.31', '24.84', '\\textbf{95.98}', '\\textbf{21.75}']
# ['inaturalist', 'textures', 'openimageo'] ['ninco', 'imagenet-o', 'ssb_hard']
# ['clip', '71.62', '86.68', '84.29', '73.15', '68.04', '88.34', '76.16', '97.88', '86.66', '77.46', '85.57', '75.73']
# ['deit', '86.64', '70.93', '87.95', '73.85', '79.83', '84.97', '91.94', '61.31', '91.12', '60.50', '91.83', '57.57']
# ['dino', '87.89', '60.78', '93.02', '36.05', '76.66', '78.36', '92.26', '57.91', '\\textbf{98.82}', '5.72', '93.24', '41.82']
# ['dinov2', '93.30', '37.34', '96.33', '16.15', '88.83', '36.56', '\\textbf{99.21}', '\\textbf{0.85}', '98.23', '\\textbf{5.25}', '97.96', '9.84']
# ['repvgg', '78.94', '80.73', '88.93', '53.15', '69.53', '89.49', '86.59', '77.72', '95.78', '21.09', '87.30', '61.26']
# ['resnet18\\_open\\_ood', '56.70', '93.67', '62.43', '89.70', '48.53', '96.10', '58.66', '93.41', '74.95', '73.41', '58.90', '91.64']
# ['resnet50d', '83.36', '73.53', '90.51', '50.75', '75.30', '85.27', '88.81', '68.10', '96.64', '18.20', '91.65', '49.15']
# ['swin', '91.28', '52.82', '92.78', '48.15', '83.99', '74.22', '98.85', '4.36', '95.23', '25.66', '96.69', '20.22']
# ['vit', '\\textbf{95.48}', '\\textbf{24.92}', '\\textbf{97.70}', '\\textbf{10.60}', '\\textbf{92.25}', '\\textbf{31.79}', '99.11', '2.70', '97.87', '6.20', '\\textbf{98.27}', '\\textbf{7.52}']
# ['mnist', 'place365', 'texture', 'svhn'] ['tin', 'cifar100']
# ['resnet18\\_open\\_ood', '\\textbf{81.15}', '\\textbf{74.80}', '\\textbf{80.12}', '\\textbf{74.68}', '\\textbf{78.53}', '\\textbf{93.49}', '\\textbf{80.06}', '\\textbf{77.56}', '\\textbf{89.16}', '\\textbf{52.20}', '\\textbf{83.85}', '\\textbf{76.82}']
# ['places365', 'mnist', 'svhn', 'texture'] ['cifar10', 'tin']
# ['resnet18\\_open\\_ood', '\\textbf{45.92}', '\\textbf{96.86}', '\\textbf{50.78}', '\\textbf{96.03}', '\\textbf{51.33}', '\\textbf{95.35}', '\\textbf{62.18}', '\\textbf{95.74}', '\\textbf{62.31}', '\\textbf{94.21}', '\\textbf{68.08}', '\\textbf{78.56}']

# %%
for k, v in results['Residual'].items():
    print(k, v.keys())
# Out:
# resnet18_32x32_cifar100_open_ood dict_keys(['cifar100'])
# resnet50d dict_keys(['imagenet200', 'imagenet', 'imagenet_sub'])
# dinov2 dict_keys(['imagenet_sub', 'imagenet', 'imagenet200'])
# repvgg dict_keys(['imagenet_sub', 'imagenet200', 'imagenet'])
# resnet18_32x32_cifar10_open_ood dict_keys(['cifar10'])
# swin dict_keys(['imagenet200', 'imagenet_sub', 'imagenet'])
# vit dict_keys(['imagenet200', 'imagenet', 'imagenet_sub'])
# deit dict_keys(['imagenet200', 'imagenet_sub', 'imagenet'])
# resnet18_224x224_imagenet200_open_ood dict_keys(['imagenet200'])
# clip dict_keys(['imagenet200', 'imagenet'])
# dino dict_keys(['imagenet200', 'imagenet_sub', 'imagenet'])
# resnet50_224x224_imagenet_open_ood dict_keys(['imagenet'])
