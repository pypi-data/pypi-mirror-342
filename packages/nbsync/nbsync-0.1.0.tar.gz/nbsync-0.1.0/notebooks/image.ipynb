# %%
# #image-50-100
import numpy as np
from PIL import Image

x = np.random.randint(0, 256, (50, 100), dtype=np.uint8)
Image.fromarray(x)
# Out:
# <PIL.Image.Image image mode=L size=100x50>

# %%
# #image-50-50
x = np.random.randint(0, 256, (50, 50), dtype=np.uint8)
Image.fromarray(x)
# Out:
# <PIL.Image.Image image mode=L size=50x50>
